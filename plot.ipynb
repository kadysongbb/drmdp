# %% [markdown]
# # 1. Model Analysis

# %% [markdown]
# ## 1.1 p_{as} = bar{p}_{as}

# %%
blue = (0.2980392156862745, 0.4470588235294118, 0.6901960784313725)
orange = (0.8666666666666667, 0.5176470588235295, 0.3215686274509804)
green = (0.3333333333333333, 0.6588235294117647, 0.40784313725490196)
red = (0.7686274509803922, 0.3058823529411765, 0.3215686274509804)

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set_style("whitegrid")

drmdpdd1_avg_reward = [-13.4394178, -16.0286067, -18.0519856, -20.4489148]
drmdpdd1_std = [0.1576426, 0.1216428, 0.2184254, 1.1991419]
mdp_avg_reward = [-13.6385117, -16.2992810, -17.8130261, -20.8187343]
mdp_std = [0.0237057, 0.2715267, 0.0570200, 0.7282281]

x = [0.6, 0.7, 0.8, 0.9]

plt.figure()
plt.errorbar(x, drmdpdd1_avg_reward, drmdpdd1_std, label = 'DD1', marker='s', capsize = 5, color = blue)
plt.errorbar(x, mdp_avg_reward, mdp_std, label = 'MDP', marker='s', capsize = 5, color = orange)

plt.legend(fontsize = 15)
plt.xticks([0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9])
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.ylabel('Total Reward    x $10^7$', fontsize = 15)
plt.xlabel('Initial Portion of Susceptibles', fontsize = 15)
# Out:
# Text(0.5,0,'Initial Portion of Susceptibles')

# %% [markdown]
# ## 1.2 construct L1 ||p_{as} - bar{p}_{as}|| <= 2

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set_style("whitegrid")

drmdpdd1_avg_reward = [-12.7783664, -16.5023790, -18.6594920, -18.9111193]
drmdpdd1_std = [0.6295830, 0.4346718, 0.6161894, 1.2401289]
mdp_avg_reward = [-13.6463480, -17.1767965, -19.1291744, -19.9009638]
mdp_std = [0.0185215, 0.3509084, 0.4676064, 1.3985478]

x = [0.6, 0.7, 0.8, 0.9]

plt.figure()
plt.errorbar(x, drmdpdd1_avg_reward, drmdpdd1_std, label = 'DD1', marker='s', capsize = 5, color = blue)
plt.errorbar(x, mdp_avg_reward, mdp_std, label = 'MDP', marker='s', capsize = 5, color = orange)

plt.legend(fontsize = 15)
plt.xticks([0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9])
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.ylabel('Total Reward    x $10^7$', fontsize = 15)
plt.xlabel('Initial Portion of Susceptibles', fontsize = 15)
# Out:
# Text(0.5,0,'Initial Portion of Susceptibles')

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

xi_dd1_9 = [100, 206, 250, 138,  44,  10,   0,   0,   0,   0,   0,   0]
xi_mdp_9 = [100, 226, 260, 134,  58,  12,   0,   0,   0,   0,   0,   0]
f_dd19 = interp1d(np.arange(1,13), xi_dd1_9, kind='quadratic')
f_mdp9 = interp1d(np.arange(1,13), xi_mdp_9, kind='quadratic')
xnew = np.linspace(1,12,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, f_dd19(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, f_mdp9(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)

r_dd1_9 = np.asarray([-6.83753247e+07,-7.48452809e+07,-3.69356381e+07,-6.99087775e+06,-1.34875273e+06,-6.15318725e+05,-1.30385160e-09,-1.30385160e-09
        ,-1.30385160e-09,-1.30385160e-09,-1.30385160e-09])/10**7
r_mdp_9 = np.asarray([-6.83753247e+07,-8.34440555e+07,-3.70326659e+07,-8.16456438e+06,-1.46931176e+06,-5.23715474e+05,-2.23517418e-09,-2.23517418e-09
        ,-2.23517418e-09,-2.23517418e-09,-2.23517418e-09])/10**7
g_dd19 = interp1d(np.arange(1,12), r_dd1_9, kind='cubic')
g_mdp9 = interp1d(np.arange(1,12), r_mdp_9, kind='cubic')
xnew = np.linspace(1,11,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, g_dd19(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, g_mdp9(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,12))
plt.xlim((1,11))
plt.ylabel('Reward at each stage     x $10^7$', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)


#####
xi_dd1_8 = [200, 304, 238,  74,  14,   0,   0,   0,   0,   0,   0,   0]
xi_mdp_8 = [200, 292, 312,  62,   6,   0,   0,   0,   0,   0,   0,   0]
f_dd18 = interp1d(np.arange(1,13), xi_dd1_8, kind='quadratic')
f_mdp8 = interp1d(np.arange(1,13), xi_mdp_8, kind='quadratic')
xnew = np.linspace(1,12,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, f_dd18(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, f_mdp8(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)

r_dd1_8 = np.asarray([-9.70685925e+07,-7.48890155e+07,-1.25486348e+07,-1.54322098e+06,-5.45456473e+05,-3.72529030e-10,
                      -3.72529030e-10,-3.72529030e-10,-3.72529030e-10,-3.72529030e-10,-3.72529030e-10])/10**7
r_mdp_8 = np.asarray([-9.70685925e+07,-8.83248171e+07,-5.32454515e+06,-2911443.989,-4.98342828e+05,-7.54465149e+04,-2.42143869e-09,
                      -2.42143869e-09,-2.42143869e-09,-2.42143869e-09,-2.42143869e-09,-2.42143869e-09])/10**7
g_dd18 = interp1d(np.arange(1,12), r_dd1_8, kind='cubic')
g_mdp8 = interp1d([1,2,3,3.5,4,5,6,7,8,9,10,11], r_mdp_8, kind='cubic')
xnew = np.linspace(1,11,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, g_dd18(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, g_mdp8(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,12))
plt.xlim((1,11))
plt.ylabel('Reward at each stage     x $10^7$', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)


#####
xi_dd1_7 = [300, 344, 144,  24,   4,   0,   0,   0,   0,   0,   0,   0]
xi_mdp_7 = [300, 354, 198,  40,   6,   0,   0,   0,   0,   0,   0,   0]
f_dd17 = interp1d(np.arange(1,13), xi_dd1_7, kind='quadratic')
f_mdp7 = interp1d(np.arange(1,13), xi_mdp_7, kind='quadratic')
xnew = np.linspace(1,12,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, f_dd17(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, f_mdp7(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)

r_dd1_7 = np.asarray([-1.09317168e+08,-4.92660890e+07,-5.40801228e+06,-8.06182049e+05,-2.26339545e+05,-5.58793545e-10,-5.58793545e-10,
                      -5.58793545e-10,-5.58793545e-10,-5.58793545e-10,-5.58793545e-10])/10**7
r_mdp_7 = np.asarray([-1.09317168e+08,-5.56570404e+07,-5.76595154e+06,-8.04816344e+05,-2.22988986e+05,-2.04890966e-09,-2.04890966e-09,
                      -2.04890966e-09,-2.04890966e-09,-2.04890966e-09,-2.04890966e-09])/10**7
g_dd17 = interp1d(np.arange(1,12), r_dd1_7, kind='cubic')
g_mdp7 = interp1d(np.arange(1,12), r_mdp_7, kind='cubic')
xnew = np.linspace(1,11,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, g_dd17(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, g_mdp7(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,12))
plt.xlim((1,11))
plt.ylabel('Reward at each stage     x $10^7$', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)

#####
xi_dd1_6 = [400, 356,  98,   8,   0,   0,   0,   0,   0,   0,   0,   0]
xi_mdp_6 = [400, 448,  62,   0,   0,   0,   0,   0,   0,   0,   0,   0]
f_dd16 = interp1d(np.arange(1,13), xi_dd1_6, kind='quadratic')
f_mdp6 = interp1d(np.arange(1,13), xi_mdp_6, kind='quadratic')
xnew = np.linspace(1,12,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, f_dd16(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, f_mdp6(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)

r_dd1_6 = np.asarray([-1.09444940e+08,-1.71380513e+07,-1.00394941e+06,-1.96723295e+05,-3.16649675e-09,-3.16649675e-09,-3.16649675e-09,-3.16649675e-09,
                     -3.16649675e-09,-3.16649675e-09,-3.16649675e-09])/10**7
r_mdp_6 = np.asarray([-1.33129632e+08,-2.99349412e+06,-1666924.206,-3.40354292e+05,-4.65661287e-09,-4.65661287e-09,-4.65661287e-09,-4.65661287e-09,-4.65661287e-09,
                     -4.65661287e-09,-4.65661287e-09,-4.65661287e-09])/10**7
g_dd16 = interp1d(np.arange(1,12), r_dd1_6, kind='cubic')
g_mdp6 = interp1d([1,2,2.5,3,4,5,6,7,8,9,10,11], r_mdp_6, kind='cubic')
xnew = np.linspace(1,11,num=1000)
plt.figure(figsize=(5,4))
plt.plot(xnew, g_dd16(xnew),'-',label = 'DD1',linewidth = 4, color = blue)
plt.plot(xnew, g_mdp6(xnew), '--',label = 'MDP',linewidth = 4, color = orange)

plt.legend(fontsize = 20)
plt.xticks(fontsize= 20)
plt.yticks(fontsize= 20)
plt.xticks(np.arange(1,12))
plt.xlim((1,11))
plt.ylabel('Reward at each stage     x $10^7$', fontsize = 20)
plt.xlabel('Time stage', fontsize = 20)

#####
# Out:
# Text(0.5,0,'Time stage')

# %% [markdown]
# ## 1.4 DD1 versus DD2

# %% [markdown]
# ###  1.4.1 p_{as} = bar{p}_{as}

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set_style("whitegrid")

drmdpdd1_avg_reward = [-2.7074462, -2.4994494, -3.3728486, -3.5798596]
drmdpdd1_std = [0.1251115, 0.1926713, 0.1399444, 0.1381766]
drmdpdd2_avg_reward = [-2.6052931, -2.5234141, -3.4787850, -3.6052550]
drmdpdd2_std = [0.1251115, 0.2064128, 0.2000153, 0.2903923]

x = [0.6, 0.7, 0.8, 0.9]

plt.figure()
plt.errorbar(x, drmdpdd1_avg_reward, yerr=drmdpdd1_std, label = 'DD1', marker='s', capsize = 5, color = blue)
plt.errorbar(x, drmdpdd2_avg_reward, yerr=drmdpdd2_std, label = 'DD2', marker='s', capsize = 5, color = orange)

plt.legend(fontsize = 15)
plt.xticks([0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9], fontsize= 15)
plt.yticks(fontsize= 15)
plt.ylabel('Total Reward    x $10^7$', fontsize = 15)
plt.xlabel('Initial Portion of Susceptibles', fontsize = 15)
# Out:
# Text(0.5,0,'Initial Portion of Susceptibles')

# %% [markdown]
# ###  1.4.2 p_{as} != bar{p}_{as}

# %%
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
sns.set_style("whitegrid")

drmdpdd1_avg_reward = [-2.5031400, -2.3972964, -2.6992930, -3.7106708]
drmdpdd1_std = [0.1021531, 0.1631839, 0.2219970, 0.2144606]
drmdpdd2_avg_reward = [-2.4009869, -2.3548787, -2.7288594, -3.7106708]
drmdpdd2_std = [0, 0.1685354, 0.2339825, 0.2144606]

x = [0.6, 0.7, 0.8, 0.9]

plt.figure()
plt.errorbar(x, drmdpdd1_avg_reward, yerr=drmdpdd1_std, label = 'DD1', marker='s', capsize = 5, color = blue)
plt.errorbar(x, drmdpdd2_avg_reward, yerr=drmdpdd2_std, label = 'DD2', marker='s', capsize = 5, color = orange)

plt.legend(fontsize = 15)
plt.xticks([0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9], fontsize= 15)
plt.yticks(fontsize= 15)
plt.ylabel('Total Reward    x $10^7$', fontsize = 15)
plt.xlabel('Initial Portion of Susceptibles', fontsize = 15)
# Out:
# Text(0.5,0,'Initial Portion of Susceptibles')

# %% [markdown]
# # 2. Sensitivity Analysis

# %% [markdown]
# ## 2.1 Willingness to pay analysis

# %%
xi_dddrmdp1_wtp1 = [100,205,270,210,95,25,5,0,0,0,0,0]
xi_dddrmdp1_wtp2 = [100,195,245,160,45,15,5,0,0,0,0,0]
xi_dddrmdp1_wtp3 = [100,215,45,65,80,70,50,35,25,15,5,0]
xi_dddrmdp1_wtp4 = [100,35,15,25,45,10,10,15,15,20,25,10]

f_wtp1 = interp1d(np.arange(1,13), xi_dddrmdp1_wtp1, kind='quadratic')
f_wtp2 = interp1d(np.arange(1,13), xi_dddrmdp1_wtp2, kind='quadratic')
f_wtp3 = interp1d(np.arange(1,13), xi_dddrmdp1_wtp3, kind='quadratic')
f_wtp4 = interp1d(np.arange(1,13), xi_dddrmdp1_wtp4, kind='quadratic')


xnew = np.linspace(1,12,num=1000)
plt.figure()
plt.plot(xnew, f_wtp1(xnew),'--',label = 'WTP = $25000/QALY',linewidth = 2, color = orange)
plt.plot(xnew, f_wtp2(xnew), '-',label = 'WTP = $50000/QALY',linewidth = 2, color = blue)
plt.plot(xnew, f_wtp3(xnew),'-.',label = 'WTP = $75000/QALY',linewidth = 2, color = green)
plt.plot(xnew, f_wtp4(xnew),':',label = 'WTP = $500000/QALY',linewidth = 2, color = red)

plt.legend(fontsize = 15)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 15)
plt.xlabel('Time stage', fontsize = 15)
# Out:
# Text(0.5,0,'Time stage')

# %% [markdown]
# ## 2.2 Vaccine price analysis

# %%
xi_dddrmdp1_vp1 = [100,170,175,85,15,0,0,0,0,0,0,0]
xi_dddrmdp1_vp2 = [100,165,185,95,25,5,5,0,0,0,0,0]
xi_dddrmdp1_vp3 = [100,195,245,160,45,15,5,0,0,0,0,0]
xi_dddrmdp1_vp4 = [100,205,280,220,85,25,10,0,0,0,0,0]

f_vp1 = interp1d(np.arange(1,13), xi_dddrmdp1_vp1, kind='quadratic')
f_vp2 = interp1d(np.arange(1,13), xi_dddrmdp1_vp2, kind='quadratic')
f_vp3 = interp1d(np.arange(1,13), xi_dddrmdp1_vp3, kind='quadratic')
f_vp4 = interp1d(np.arange(1,13), xi_dddrmdp1_vp4, kind='quadratic')

xnew = np.linspace(1,12,num=1000)
plt.figure()
plt.plot(xnew, f_vp1(xnew),'--', label = 'vaccine price = $5000',linewidth = 2, color = orange)
plt.plot(xnew, f_vp2(xnew),'-.',label = 'vaccine price = $12500',linewidth = 2, color = green)
plt.plot(xnew, f_vp3(xnew),'-',label = 'vaccine price = $25000',linewidth = 2, color = blue)
plt.plot(xnew, f_vp4(xnew),':',label = 'vaccine price = $37500',linewidth = 2, color = red)

plt.legend(fontsize = 15)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 15)
plt.xlabel('Time stage', fontsize = 15)
# Out:
# Text(0.5,0,'Time stage')

# %% [markdown]
# ## 2.3 kT analysis

# %%
xi_dddrmdp1_kT1 = [100,40,20,35,30,20,40,25,40,35,20,5] 
xi_dddrmdp1_kT2 = [100,35,70,135,100,110,95,80,50,25,10,5]
xi_dddrmdp1_kT3 = [100,195,245,160,45,15,5,0,0,0,0,0]
xi_dddrmdp1_kT4 = [100,205,250,145,45,10,0,0,0,0,0,0]

f_kt1 = interp1d(np.arange(1,13), xi_dddrmdp1_kT1, kind='quadratic')
f_kt2 = interp1d(np.arange(1,13), xi_dddrmdp1_kT2, kind='quadratic')
f_kt3 = interp1d(np.arange(1,13), xi_dddrmdp1_kT3, kind='quadratic')
f_kt4 = interp1d(np.arange(1,13), xi_dddrmdp1_kT4, kind='quadratic')

xnew = np.linspace(1,12,num=1000)
plt.figure()
plt.plot(xnew, f_kt1(xnew),'--', label = 'kT = 0.5 x $10^6$',linewidth = 2, color = orange)
plt.plot(xnew, f_kt2(xnew),'-.',label = 'kT = 1.5 x $10^6$',linewidth = 2, color = green)
plt.plot(xnew, f_kt3(xnew),'-',label = 'kT = 2.5 x $10^6$',linewidth = 2, color = blue)
plt.plot(xnew, f_kt4(xnew),':',label = 'kT = 3.5 x $10^6$',linewidth = 2, color = red)

plt.legend(fontsize = 15)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 15)
plt.xlabel('Time stage', fontsize = 15)
# Out:
# Text(0.5,0,'Time stage')

# %% [markdown]
# ## 2.4 Tau analysis

# %%
xi_dddrmdp1_tau1 = [100,125,140,120,100,60,30,15,5,5,0,0]
xi_dddrmdp1_tau2 = [100,195,245,160,45,15,5,0,0,0,0,0]
xi_dddrmdp1_tau3 = [100,270,75,100,110,80,35,15,5,0,0,0]
xi_dddrmdp1_tau4 = [100,80,260,95,120,80,35,15,5,0,0,0]

f_tau1 = interp1d(np.arange(1,13), xi_dddrmdp1_tau1, kind='quadratic')
f_tau2 = interp1d(np.arange(1,13), xi_dddrmdp1_tau2, kind='quadratic')
f_tau3 = interp1d(np.arange(1,13), xi_dddrmdp1_tau3, kind='quadratic')
f_tau4 = interp1d(np.arange(1,13), xi_dddrmdp1_tau4, kind='quadratic')

xnew = np.linspace(1,12,num=1000)
plt.figure()
plt.plot(xnew, f_tau1(xnew),'--', label = r'$\tau$ = 0.3',linewidth = 2, color = orange)
plt.plot(xnew, f_tau2(xnew),'-',label = r'$\tau$ = 0.5',linewidth = 2, color = blue)
plt.plot(xnew, f_tau3(xnew),'-.',label = r'$\tau$ = 0.7',linewidth = 2, color = green)
plt.plot(xnew, f_tau4(xnew),':',label = r'$\tau$ = 0.9',linewidth = 2, color = red)

plt.legend(fontsize = 15)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.xticks(np.arange(1,13))
plt.xlim((1,12))
plt.ylabel('Number of infectives', fontsize = 15)
plt.xlabel('Time stage', fontsize = 15)
# Out:
# Text(0.5,0,'Time stage')
